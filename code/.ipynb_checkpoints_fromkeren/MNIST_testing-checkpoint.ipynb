# %% [markdown]
# # MNIST

# %%
import torch
from torchvision import datasets, transforms
import numpy as np
from matplotlib import pyplot as plt
import random
import argparse
from torch.utils.data import DataLoader, Subset, random_split
import os

import torch.nn as nn
import torch.optim as optim

from utils import plot_tsne
# Out:
# /home/kerenmizrahi/miniconda3/envs/cs236781-hw/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/kerenmizrahi/miniconda3/envs/cs236781-hw/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZNK3c107SymBool10guard_boolEPKcl'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# ##### Load and prepare data

# %%
def freeze_seeds(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

freeze_seeds(116)

# normalize data
transform = transforms.Compose([
    transforms.ToTensor(),  
    transforms.Normalize(mean=[0.5], std=[0.5])  # MNIST has 1 channel
])


dataset_path = '/datasets/cv_datasets/data'
batch_size = 64

# Load MNIST from the given path
ds_train = datasets.MNIST(root=dataset_path, train=True, download=False, transform=transform)
ds_validation = datasets.MNIST(root=dataset_path, train=False, download=False, transform=transform)

# dataset split: 
# train + test (during training)
# validation

# Split  80% train  20% test
train_size = int(0.8 * len(ds_train))  
test_size = len(ds_train) - train_size  
ds_train, ds_test = random_split(ds_train, [train_size, test_size])

# DataLoaders
dl_train = DataLoader(ds_train, batch_size=batch_size, shuffle=True)
dl_test = DataLoader(ds_test, batch_size=batch_size, shuffle=True)
dl_val = DataLoader(ds_validation, batch_size=batch_size, shuffle=True)


# Example - [batch_size, 1, 28, 28]
for image, label in dl_train:
    print(image.shape)
    print(label[0])
    img = image[0].squeeze(0)  
    plt.figure(figsize=(1, 1))  
    plt.imshow(img.cpu().numpy(), cmap='gray')
    plt.axis('off')  
    plt.show()

    break
# Out:
# torch.Size([64, 1, 28, 28])
# tensor(9)

# %% [markdown]
# ## 1.2.1

# %% [markdown]
# ##### Initialize Autoencoder

# %%
import MNIST.autoencoder as autoencoder

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

encoder = autoencoder.Encoder().to(device)
decoder = autoencoder.Decoder().to(device)
autoencoder_model = autoencoder.Autoencoder(encoder, decoder).to(device)
# Out:
# encoder.0.weight: requires_grad = True
# encoder.0.bias: requires_grad = True
# encoder.3.weight: requires_grad = True
# encoder.3.bias: requires_grad = True
# encoder.7.weight: requires_grad = True
# encoder.7.bias: requires_grad = True
# Original Min: -1.0, Max: 1.0
# Reconstructed Min: -0.009321361780166626, Max: 0.5166357755661011

# %% [markdown]
# ##### Train AutoEncoder (self-supervised)

# %%
loss_fn = nn.L1Loss() # MAE loss 
optimizer = optim.Adam(autoencoder_model.parameters(), lr=0.001)
num_epochs = 5

trainer = autoencoder.autoencoderTrainer(autoencoder_model, dl_train, dl_test, loss_fn, optimizer, num_epochs, device)
trainer.trainAutoencoder()
# Out:
# Epoch 1:
#     train reconstruction error (Loss): 0.2490, Train Accuracy: 75.10%
#     Test reconstruction error (Loss): 0.1499, Test Accuracy: 85.01%
# Epoch 2:
#     train reconstruction error (Loss): 0.1302, Train Accuracy: 86.98%
#     Test reconstruction error (Loss): 0.1083, Test Accuracy: 89.17%
# Epoch 3:
#     train reconstruction error (Loss): 0.1082, Train Accuracy: 89.18%
#     Test reconstruction error (Loss): 0.0969, Test Accuracy: 90.31%
# Epoch 4:
#     train reconstruction error (Loss): 0.0967, Train Accuracy: 90.33%
#     Test reconstruction error (Loss): 0.0880, Test Accuracy: 91.20%
# Epoch 5:
#     train reconstruction error (Loss): 0.0910, Train Accuracy: 90.90%
#     Test reconstruction error (Loss): 0.0855, Test Accuracy: 91.45%
# reconstruction error (in mean absolute error, from last epoch): 0.09

# %% [markdown]
# #### print tsne output

# %%
import matplotlib.image as mpimg

plot_tsne(encoder, dl_test, "MNIST", device)

orig_img = 'MNIST/image_tsne.png'
reconstructed_img = 'MNIST/latent_tsne.png'

plt.figure(figsize=(30, 30))

img = mpimg.imread(orig_img)
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.axis('off')  

img = mpimg.imread(reconstructed_img)
plt.subplot(1, 2, 2)
plt.imshow(img)
plt.axis('off') 

plt.show()

# %%
num_images = 5
indices = random.sample(range(len(dl_test.dataset)), num_images)

orig_img = []
rec_img = []

for idx in indices:
    img, label = dl_test.dataset[idx]
    img = img.squeeze(0)   # (1, 28, 28) -> (28, 28)
    orig_img.append(img)

    img = img.to(device)
    img = img.unsqueeze(0)
    img = img.unsqueeze(0)
    encoded_img = encoder(img)
    encoded_img = encoded_img.view(encoded_img.size(0), -1)
    r_img = decoder(encoded_img)
    rec_img.append(r_img)
    
plt.figure(figsize=(5, 5))
for i, (a, b) in enumerate(zip(orig_img, rec_img)):
    plt_axis = plt.subplot(2, num_images, i + 1)
    plt.title('before')
    plt.imshow(a.cpu().numpy(), cmap='gray')
    plt.axis('off')
    b = b.detach().cpu().numpy()
    b = b.squeeze(0)
    b = b.squeeze(0)
    plt_axis = plt.subplot(2, num_images, i + 1 + num_images)
    plt.title('after')
    plt.imshow(b, cmap='gray')
    plt.axis('off')

plt.show()

# %% [markdown]
# #### Initialize classifier (use pre-trained encoder)

# %%
import MNIST.classifier as clf

classifier = clf.Classifier().to(device)

# %% [markdown]
# #### Train Classifier (fully-supervised training + freeze encoder)

# %%
hyperparams = {
    'loss_fn': torch.nn.CrossEntropyLoss(),
    'optimizer' : optim.Adam,    
    'learning_rate': 0.001,  
    'num_epochs': 5,            
}

freeze_encoder = True

trainer = clf.clfTrainer(classifier, encoder, dl_train, dl_test,
                                 hyperparams, freeze_encoder, device)
train_acc, test_acc = trainer.trainClassifier()
# Out:
# Epoch 1:
#     Train Loss: 0.9646, Train Accuracy: 77.43%
#     Test Loss: 0.4425, Test Accuracy: 88.04%
# Epoch 2:
#     Train Loss: 0.3825, Train Accuracy: 89.11%
#     Test Loss: 0.3564, Test Accuracy: 89.61%
# Epoch 3:
#     Train Loss: 0.3385, Train Accuracy: 90.10%
#     Test Loss: 0.3336, Test Accuracy: 90.12%
# Epoch 4:
#     Train Loss: 0.3195, Train Accuracy: 90.48%
#     Test Loss: 0.3191, Test Accuracy: 90.53%
# Epoch 5:
#     Train Loss: 0.3045, Train Accuracy: 90.89%
#     Test Loss: 0.3065, Test Accuracy: 90.84%

# %% [markdown]
# #### Test Classifier on Validation

# %%
val_loss, val_accuracy = trainer.evalClassifier(dl_val)
# Out:
# Validation Loss: 0.2797, Validation Accuracy: 91.79%

# %% [markdown]
# #### plot downstream *classification* accuracy over - training, validation, test sets

# %%
# Plot Train Accuracy over Epochs
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, marker='o', linestyle='-', color='b', label='Train Accuracy')
plt.title("Train Accuracy")
plt.xlabel("# Epoch")
plt.ylabel("Accuracy(%)")
plt.grid(True)
plt.legend()

# Plot Test Loss over Iterations
plt.subplot(1, 2, 1)
plt.plot(range(1, len(test_acc) + 1), test_acc, marker='s', linestyle='-', color='g', label='Test Accuracy')
plt.title("Test Accuracy")
plt.xlabel("# Epoch")
plt.ylabel("Accuracy(%)")
plt.grid(True)
plt.legend()

# Display the graphs
plt.tight_layout()
plt.show()

# %% [markdown]
# #### hyperparameter tunning

# %%
'''
piazza - can explain in words what we did in order to tune. (check again)
'''
# Out:
# '\npiazza - can explain in words what we did in order to tune. (check again)\n'

# %% [markdown]
# ## 1.2.2

# %% [markdown]
# #### Initialize classifier + encoder

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

encoder2 = autoencoder.Encoder().to(device)
classifier2 = clf.Classifier().to(device)

# %% [markdown]
# #### Train encoder & classifier JOINTLY

# %%
hyperparams = {
    'loss_fn': torch.nn.CrossEntropyLoss(),
    'optimizer' : optim.Adam,  
    'learning_rate': 0.001,  
    'num_epochs': 5,            
}
freeze_encoder = False

trainer = clf.clfTrainer(classifier2, encoder2, dl_train, dl_test,
                                 hyperparams, freeze_encoder, device)
train_acc, test_acc = trainer.trainClassifier()
# Out:
# Epoch 1:
#     Train Loss: 0.1811, Train Accuracy: 94.30%
#     Test Loss: 0.0782, Test Accuracy: 97.69%
# Epoch 2:
#     Train Loss: 0.0544, Train Accuracy: 98.23%
#     Test Loss: 0.0602, Test Accuracy: 98.36%
# Epoch 3:
#     Train Loss: 0.0419, Train Accuracy: 98.69%
#     Test Loss: 0.0517, Test Accuracy: 98.49%
# Epoch 4:
#     Train Loss: 0.0346, Train Accuracy: 98.88%
#     Test Loss: 0.0644, Test Accuracy: 98.19%
# Epoch 5:
#     Train Loss: 0.0248, Train Accuracy: 99.19%
#     Test Loss: 0.0529, Test Accuracy: 98.52%

# %%
val_loss, val_accuracy = trainer.evalClassifier(dl_val)

# Plot Train Accuracy over Epochs
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, marker='o', linestyle='-', color='b', label='Train Accuracy')
plt.title("Train Accuracy")
plt.xlabel("# Epoch")
plt.ylabel("Accuracy(%)")
plt.grid(True)
plt.legend()

# Plot Test Loss over Iterations
plt.subplot(1, 2, 1)
plt.plot(range(1, len(test_acc) + 1), test_acc, marker='s', linestyle='-', color='g', label='Test Accuracy')
plt.title("Test Accuracy")
plt.xlabel("# Epoch")
plt.ylabel("Accuracy(%)")
plt.grid(True)
plt.legend()

# Display the graphs
plt.tight_layout()
plt.show()
# Out:
# Validation Loss: 0.0343, Validation Accuracy: 99.06%
